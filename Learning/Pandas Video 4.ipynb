# %%
import pandas as pd

# Read the Excel file without treating the first row as headers
df = pd.read_excel(r'C:\Users\Ali Muhtasham Javed\Downloads\indian_startup_funding_Lab1.xlsx')
#df.loc[0:112].. can be used to get data in tabular form.. 
df
# Out:
#      Stock           Unnamed: 1  \
# 0    Sr No                 Date
# 1       17  2019-12-20 00:00:00
# 2       12  2019-12-17 00:00:00
# 3       13  2019-12-16 00:00:00
# 4       14  2019-12-16 00:00:00
# ..     ...                  ...
# 107    114  2019-02-08 00:00:00
# 108    113  2019-02-01 00:00:00
# 109    118  2019-01-04 00:00:00
# 110    119  2019-01-04 00:00:00
# 111    117  2019-01-03 00:00:00
#
#                                             Unnamed: 2  \
# 0                                         Startup Name
# 1                                         Lenskart.com
# 2                                           Healthians
# 3                                              Licious
# 4                                               InCred
# ..                                                 ...
# 107                                            Zilingo
# 108                                             FleetX
# 109                            Vyome Therapeutics Inc.
# ...

# %%
import pandas as pd

# Read the Excel file without treating the first row as headers
df = pd.read_excel(r'C:\Users\Ali Muhtasham Javed\Downloads\indian_startup_funding_Lab1.xlsx',header = 1)
df


#if there are no column names following code can help in naming the column names .
#df = pd.read_excel(r'C:\Users\Ali Muhtasham Javed\Downloads\indian_startup_funding_Lab1.xlsx',header = 1, names = ['A','B','C'])
# Out:
#      Sr No       Date                                       Startup Name  \
# 0       17 2019-12-20                                       Lenskart.com
# 1       12 2019-12-17                                         Healthians
# 2       13 2019-12-16                                            Licious
# 3       14 2019-12-16                                             InCred
# 4       15 2019-12-14                                              Trell
# ..     ...        ...                                                ...
# 106    114 2019-02-08                                            Zilingo
# 107    113 2019-02-01                                             FleetX
# 108    118 2019-01-04                            Vyome Therapeutics Inc.
# 109    119 2019-01-04  Samunnati Financial Intermediation & Services ...
# 110    117 2019-01-03                                           CarDekho
#
#                 Industry Vertical                               SubVertical  \
# ...

# %%
df = df.sort_values(by= 'Sr No', ascending=True)
df
#indexing ruined.
# Out:
#      Sr No       Date                                       Startup Name  \
# 6        8 2019-12-12                                             Ecozen
# 8        9 2019-12-06                                           CarDekho
# 9       10 2019-12-03                                       Dhruva Space
# 5       11 2019-12-13                                             Rivigo
# 1       12 2019-12-17                                         Healthians
# ..     ...        ...                                                ...
# 106    114 2019-02-08                                            Zilingo
# 105    115 2019-02-13                                   NanoClean Global
# 110    117 2019-01-03                                           CarDekho
# 108    118 2019-01-04                            Vyome Therapeutics Inc.
# 109    119 2019-01-04  Samunnati Financial Intermediation & Services ...
#
#                 Industry Vertical                       SubVertical  \
# ...

# %%
df.reset_index(drop = True)
# Out:
#      Sr No       Date                                       Startup Name  \
# 0        8 2019-12-12                                             Ecozen
# 1        9 2019-12-06                                           CarDekho
# 2       10 2019-12-03                                       Dhruva Space
# 3       11 2019-12-13                                             Rivigo
# 4       12 2019-12-17                                         Healthians
# ..     ...        ...                                                ...
# 106    114 2019-02-08                                            Zilingo
# 107    115 2019-02-13                                   NanoClean Global
# 108    117 2019-01-03                                           CarDekho
# 109    118 2019-01-04                            Vyome Therapeutics Inc.
# 110    119 2019-01-04  Samunnati Financial Intermediation & Services ...
#
#                 Industry Vertical                       SubVertical  \
# ...

# %%
#to manually give the name to the columns header. 

import pandas as pd

# Read the Excel file without treating the first row as headers
#df = pd.read_excel(r'C:\Users\Ali Muhtasham Javed\Downloads\indian_startup_funding_Lab1.xlsx', header = None, names=['A', 'B','C'])
#df.loc[0:112].. can be used to get data in tabular form.. 
#df

# %%
#if only selected number of rows needs to be read

df = pd.read_excel(r'C:\Users\Ali Muhtasham Javed\Downloads\indian_startup_funding_Lab1.xlsx', header = 1, nrows = 2)
df_sorted = df.sort_values(by = 'Sr No', ascending=True). reset_index(drop= True)
print(df_sorted)
df[]
# Out:
#    Sr No       Date  Startup Name             Industry Vertical  \
# 0     12 2019-12-17    Healthians  B2B-focused foodtech startup
# 1     17 2019-12-20  Lenskart.com                    E-Commerce
#
#                       SubVertical City  Location  \
# 0    Food Solutions For Corporate      Bengaluru
# 1  Online Eyewear Shopping Portal      Faridabad
#
#                             Investors Name InvestmentnType  Amount in USD  \
# 0  Paytm, NPTK, Sabre Partners and Neoplux        Series C       12000000
# 1                     SoftBank Vision Fund        Series G      231000000
#
#    Remarks
# 0      NaN
# 1      NaN
